# %% [markdown]
# ### Step 2 - Add new steps and evaluate

# %%
import pandas as pd
import numpy as np
from mlpl import fe, prep, models, vis, utils, encodingpred
from mlpl.pipetools import pipe, pmodels, pdefaults, steps, putils
from sklearn.model_selection import KFold
import sklearn
import os
from hyperopt import hp
import warnings
from sklearn.linear_model import LogisticRegression

warnings.filterwarnings('ignore')
pd.set_option('precision', 3)
pd.set_option('float_format', '{:.3f}'.format)
np.random.seed(42)
#label_name = 'Survived'

example_sub_path = 'data/gender_submission.csv'
sub = pd.read_csv(example_sub_path)

# %% [markdown]
# ### Load Pipeline

# %%
lr_pipeline = pipe.Pipeline(project_path = 'lr_pipeline')
# Out:
# A project exists on this path, loading...
# Load cols_to_drop from: BASELINE_colstodrop
# baseline model found.
# loading model params
# Project loaded from lr_pipeline

# %% [markdown]
# ### Try New Steps

# %% [markdown]
# ### Generalizable FE/Preprocessing
# - Click on feature names to see steps
#
# - A number of preprocessing steps are tried on columns. <br>
# Right now, they mostly consist of alternative imputations to baseline.<br>
#
# - I already coded some automated FE methods, but they are not in default steps yet.

# %% [markdown]
# - Note that some steps are considered useless despite they improve the<br>
# cv metric. Steps that increase the cv less than **'useful_limit'** will not be applied.<br>
# This parameter was set in baseline stage.
#
# - The reason for that is some steps will overfit to the cv and you should keep only<br>
# the ones that result in a significant improvement. This is especially the case for projects<br>
# with a small dataset.

# %%
steps.try_default_nominal_steps(lr_pipeline,
                                ohe = True,
                                group_outliers = True,
                                ohe_max_unique = 5000)
# Out:
#             <style>
#                 .collapsible {
#                   background-color: #777;
#                   color: white;
#                   cursor: pointer;
#                   padding: 18px;
#                   text-align: left;
#                   outline: none;
#                   font-size: 15px;
#                   font-weight: 700;
#                   border-radius: 5px 5px 5px 5px;
#                 }
#                 .active, .collapsible:hover {
#                   background-color: #555;
#                 }
#
#                 .container {
#                   display: none;
#                   background-color: inherit;
#                 }
#                 </style>
#           <div style="border:2px solid; border-radius: 15px; display: block; padding:2em; background: None"><div style= "font-size:large;color:None;font-weight:700">Try Steps for Categoricals: </div><div style= "font-size:initial;color:None;font-weight:400">['Sex', 'Ticket', 'Cabin', 'Embarked']</div></div><div></div><button type="button" style="width: 97%; border: 1px solid #4E4E4E" class="collapsible collapsible_box"><span style= "font-size:{};;font-weight:700">Sex</span></button><div style="border:2px solid; border-radius: 15px; display: none; padding:2em; background: None"><div style= "font-size:initial;color:None;font-weight:400">Will not OHE, bin or group Sex (less than 3 distinct values.)</div><div style= "font-size:initial;color:None;font-weight:400">No steps available for Sex</div></div><div></div><button type="button" style="width: 97%; border: 1px solid #4E4E4E" class="collapsible collapsible_box"><span style= "font-size:{};;font-weight:700">Ticket</span></button><div style="border:2px solid; border-radius: 15px; display: none; padding:2em; background: None"><div style= "font-size:large;color:None;font-weight:700">Steps to evaluate: </div><span style= "font-size:initial;color:None;font-weight:400">['one_hot_encode_(col_name=label_encode_Ticket)', 'one_hot_encode_(col_name=label_encode_Ticket)_ohe', 'one_hot_encode_(col_name=label_encode_Ticket)_group_outliers', 'one_hot_encode_(col_name=label_encode_Ticket)_group_outliers_ohe']</span><div></div><button type="button" style="width: 97%; border: 1px solid #4E4E4E" class="collapsible collapsible_box"><span style= "font-size:{};color:#680000;font-weight:700">one_hot_encode_(col_name=label_encode_Ticket) : +0.0007490636704122755</span></button><div style="border:2px solid; border-radius: 15px; display: none; padding:2em; background: None"><div></div><button type="button" style="width: 97%" class="collapsible">Processing</button><div class="div.input_area container"><div style= "font-size:initial;color:None;font-weight:400">ohe: label_encode_Ticket</div><div style= "font-size:initial;color:None;font-weight:400"></div></div>
#         <style>
#         hr {
#           display: block;
#           margin-top: 0.5em;
#           margin-bottom: 0.5em;
#           margin-left: auto;
#           margin-right: auto;
#           border-style: inset;
#           border-width: 1px;
#         }
#         </style> <hr><div></div><button type="button" style="width: 97%" class="collapsible">Training</button><div class="div.input_area container"><div style= "font-size:large;color:None;font-weight:700">Columns to use: </div><span style= "font-size:initial;color:None;font-weight:400">['Parch', 'Pclass', 'SibSp', 'label_encode_Sex', 'label_encode_Ticket_ohe', 'process_dense_Age', 'process_dense_Fare', 'process_nominal_label_encode_Cabin', 'process_nominal_label_encode_Embarked']</span><div style= "font-size:initial;color:None;font-weight:400">Do line search</div><div style= "font-size:initial;color:None;font-weight:400"><b>NONSPARSE DTYPES:</b></div><div style= "font-size:initial;color:None;font-weight:400">Parch                                       int64</div><div style= "font-size:initial;color:None;font-weight:400">Pclass                                      int64</div><div style= "font-size:initial;color:None;font-weight:400">SibSp                                       int64</div><div style= "font-size:initial;color:None;font-weight:400">label_encode_Sex                         category</div><div style= "font-size:initial;color:None;font-weight:400">process_dense_Age                         float64</div><div style= "font-size:initial;color:None;font-weight:400">process_dense_Fare                        float64</div><div style= "font-size:initial;color:None;font-weight:400">process_nominal_label_encode_Cabin       category</div><div style= "font-size:initial;color:None;font-weight:400">process_nominal_label_encode_Embarked    category</div><div style= "font-size:initial;color:None;font-weight:400">dtype: object</div><div style= "font-size:initial;color:None;font-weight:400">Will not use high cardinality categoricals for linear models:</div><div style= "font-size:initial;color:None;font-weight:400">['process_nominal_label_encode_Cabin', 'process_nominal_label_encode_Embarked']</div><div style= "font-size:initial;color:None;font-weight:400"><b>STANDARDIZE:</b></div><div style= "font-size:initial;color:None;font-weight:400">Parch</div><div style= "font-size:initial;color:None;font-weight:400">Pclass</div><div style= "font-size:initial;color:None;font-weight:400">SibSp</div><div style= "font-size:initial;color:None;font-weight:400">process_dense_Age</div><div style= "font-size:initial;color:None;font-weight:400">process_dense_Fare</div><div style= "font-size:initial;color:None;font-weight:400">label_encode_Sex</div><div style= "font-size:initial;color:None;font-weight:400"><b>TRN COLS TO USE:</b></div><div style= "font-size:initial;color:None;font-weight:400">{'SibSp_std', 'label_encode_Sex_std', 'process_dense_Fare_std', 'Pclass_std', 'label_encode_Ticket_ohe', 'process_dense_Age_std', 'Parch_std'}</div><div style= "font-size:initial;color:None;font-weight:400">(891, 935)</div><div style= "font-size:initial;color:None;font-weight:400"><b>NONSPARSE DTYPES:</b></div><div style= "font-size:initial;color:None;font-weight:400">Parch                                       int64</div><div style= "font-size:initial;color:None;font-weight:400">Pclass                                      int64</div><div style= "font-size:initial;color:None;font-weight:400">SibSp                                       int64</div><div style= "font-size:initial;color:None;font-weight:400">label_encode_Sex                         category</div><div style= "font-size:initial;color:None;font-weight:400">process_dense_Age                         float64</div><div style= "font-size:initial;color:None;font-weight:400">process_dense_Fare                        float64</div><div style= "font-size:initial;color:None;font-weight:400">process_nominal_label_encode_Cabin       category</div><div style= "font-size:initial;color:None;font-weight:400">process_nominal_label_encode_Embarked    category</div><div style= "font-size:initial;color:None;font-weight:400">dtype: object</div><div style= "font-size:initial;color:None;font-weight:400">Will not use high cardinality ca ...

# %%
# Not better than the baseline
steps.try_default_numeric_steps(lr_pipeline,
                                ohe = True,
                                binning = True)
# Out:
#             <style>
#                 .collapsible {
#                   background-color: #777;
#                   color: white;
#                   cursor: pointer;
#                   padding: 18px;
#                   text-align: left;
#                   outline: none;
#                   font-size: 15px;
#                   font-weight: 700;
#                   border-radius: 5px 5px 5px 5px;
#                 }
#                 .active, .collapsible:hover {
#                   background-color: #555;
#                 }
#
#                 .container {
#                   display: none;
#                   background-color: inherit;
#                 }
#                 </style>
#           <div style="border:2px solid; border-radius: 15px; display: block; padding:2em; background: None"><div style= "font-size:large;color:None;font-weight:700">Try Steps for Numerics: </div><div style= "font-size:initial;color:None;font-weight:400">['Pclass', 'Age', 'SibSp', 'Parch', 'Fare']</div></div><div></div><button type="button" style="width: 97%; border: 1px solid #4E4E4E" class="collapsible collapsible_box"><span style= "font-size:{};;font-weight:700">Pclass</span></button><div style="border:2px solid; border-radius: 15px; display: none; padding:2em; background: None"><div style= "font-size:initial;color:None;font-weight:400">Will not BIN Pclass, as it has n_unique= 3.0 < 25</div><div style= "font-size:large;color:None;font-weight:700">Steps to evaluate: </div><span style= "font-size:initial;color:None;font-weight:400">['bin_numeric_auto_(col_name=Pclass)', 'bin_numeric_auto_(col_name=Pclass)_binning', 'bin_numeric_auto_(col_name=Pclass)_ohe', 'bin_numeric_auto_(col_name=Pclass)_ohe_binning']</span><div></div><button type="button" style="width: 97%; border: 1px solid #4E4E4E" class="collapsible collapsible_box"><span style= "font-size:{};color:#680000;font-weight:700">bin_numeric_auto_(col_name=Pclass) : -0.008599585713389035</span></button><div style="border:2px solid; border-radius: 15px; display: none; padding:2em; background: None"><div></div><button type="button" style="width: 97%" class="collapsible">Processing</button><div class="div.input_area container"><div style= "font-size:initial;color:None;font-weight:400">Skip Pclass, nunique = 3</div><div style= "font-size:initial;color:None;font-weight:400"></div></div>
#         <style>
#         hr {
#           display: block;
#           margin-top: 0.5em;
#           margin-bottom: 0.5em;
#           margin-left: auto;
#           margin-right: auto;
#           border-style: inset;
#           border-width: 1px;
#         }
#         </style> <hr><div></div><button type="button" style="width: 97%" class="collapsible">Training</button><div class="div.input_area container"><div style= "font-size:large;color:None;font-weight:700">Columns to use: </div><span style= "font-size:initial;color:None;font-weight:400">['Parch', 'SibSp', 'label_encode_Sex', 'label_encode_Ticket', 'process_dense_Age', 'process_dense_Fare', 'process_nominal_label_encode_Cabin', 'process_nominal_label_encode_Cabin_ohe', 'process_nominal_label_encode_Embarked']</span><div style= "font-size:initial;color:None;font-weight:400">Do line search</div><div style= "font-size:initial;color:None;font-weight:400"><b>NONSPARSE DTYPES:</b></div><div style= "font-size:initial;color:None;font-weight:400">Parch                                       int64</div><div style= "font-size:initial;color:None;font-weight:400">SibSp                                       int64</div><div style= "font-size:initial;color:None;font-weight:400">label_encode_Sex                         category</div><div style= "font-size:initial;color:None;font-weight:400">label_encode_Ticket                      category</div><div style= "font-size:initial;color:None;font-weight:400">process_dense_Age                         float64</div><div style= "font-size:initial;color:None;font-weight:400">process_dense_Fare                        float64</div><div style= "font-size:initial;color:None;font-weight:400">process_nominal_label_encode_Cabin        float64</div><div style= "font-size:initial;color:None;font-weight:400">process_nominal_label_encode_Embarked    category</div><div style= "font-size:initial;color:None;font-weight:400">dtype: object</div><div style= "font-size:initial;color:None;font-weight:400">Will not use high cardinality categoricals for linear models:</div><div style= "font-size:initial;color:None;font-weight:400">['label_encode_Ticket', 'process_nominal_label_encode_Embarked']</div><div style= "font-size:initial;color:None;font-weight:400"><b>STANDARDIZE:</b></div><div style= "font-size:initial;color:None;font-weight:400">Parch</div><div style= "font-size:initial;color:None;font-weight:400">SibSp</div><div style= "font-size:initial;color:None;font-weight:400">process_dense_Age</div><div style= "font-size:initial;color:None;font-weight:400">process_dense_Fare</div><div style= "font-size:initial;color:None;font-weight:400">process_nominal_label_encode_Cabin</div><div style= "font-size:initial;color:None;font-weight:400">label_encode_Sex</div><div style= "font-size:initial;color:None;font-weight:400"><b>TRN COLS TO USE:</b></div><div style= "font-size:initial;color:None;font-weight:400">{'SibSp_std', 'process_nominal_label_encode_Cabin_ohe', 'label_encode_Sex_std', 'process_dense_Fare_std', 'process_dense_Age_std', 'process_nominal_label_encode_Cabin_std', 'Parch_std'}</div><div style= "font-size:initial;color:None;font-weight:400">(891, 8)</div><div style= "font-size:initial;color:None;font-weight:400"><b>NONSPARSE DTYPES:</b></div><div style= "font-size:initial;color:None;font-weight:400">Parch                                       int64</div><div style= "font-size:initial;color:None;font-weight:400">SibSp                                       int64</div><div style= "font-size:initial;color:None;font-weight:400">label_encode_Sex                         category</div><div style= "font-size:initial;color:None;font-weight:400">label_encode_Ticket                      category</div><div style= "font-size:initial;color:None;font-weight:400">process_dense_Age                         float64</div><div style= "font-size:initial;color:None;font-weight:400">process_dense_Fare                        float64</div><div style= "font-size:initial;color:None;font-weight:400">process_nominal_label_encode_Cabin        float64</div><div style= "font-size:initial;color:None;font-weight:400">process_nominal_label_encode_Embarked    category</div><div style= "font-size:initial;color:None;font-weight:400">dtype: object</div><div styl ...

# %% [markdown]
# #### Baseline score: 0.76555
# #### Leaderboard score after default steps: 0.78468

# %% [markdown]
# ### Custom FE

# %% [markdown]
# #### Add title

# %%
# Extract title from Name

def add_title(feature_properties, train, test, label_name):
    # From: https://www.kaggle.com/kpacocha/top-5-titanic-machine-learning-from-disaster
    def fe_title(df, col):
        title_col = df.Name.str.extract(' ([A-Za-z]+)\.', expand=False)
        title_col = np.where((title_col=='Capt') | (title_col=='Countess')
                           | (title_col=='Don') | (title_col=='Dona')
                           | (title_col=='Jonkheer') | (title_col=='Lady')
                           | (title_col=='Sir') | (title_col=='Major')
                           | (title_col=='Rev') | (title_col=='Col'),
                           'Other',title_col)
        
        title_col = pd.Series(title_col)
        title_col = title_col.replace('Ms','Miss')
        title_col = title_col.replace('Mlle','Miss')
        title_col = title_col.replace('Mme','Mrs')
        return title_col
    
    # utils.utilize is a python decorator that transforms a function from:
    # - takes dataframe, column name as input, returns pd.Series
    # to:
    # - takes multiple dataframes, can return a pd.Series, can add new column to
    #   dataframes with a new name or replaces the original.
    #   This behavior is controlled by 'mode' argument.
    #  mode:
    #  - 'add': add resulting column to the dataframe with a generated name
    #  - 'replace': replace original column. 
    #  - 'return' : return pd.Series for each df.
    #  
    # utilize also has join_dfs argument (default=True)
    # if join_dfs = True, operation is carried out after concatenating the column
    # from dataframes.
    
    # Process name, append result to train and test.
    utils.utilize(mode = 'add')(fe_title)([train, test], 'Name')
    
    # This is the name of the added column.
    # Names are generated by utilize using this template:
    #     '{function_name}_{col}'
    #
    # (This is if col is a single string. It can be a list)
    
    new_name = 'fe_title_Name'
    
    # Label encode new column and replace it.
    utils.utilize(mode = 'replace')(prep.label_encode)([train, test], new_name)
    
    # One hot encode new column
    train, test = prep.one_hot_encode([train, test], col = new_name, sparse = True)
    return [], train, test

res = lr_pipeline.add_step_apply_if_useful(proc = add_title)
# Out:
#             <style>
#                 .collapsible {
#                   background-color: #777;
#                   color: white;
#                   cursor: pointer;
#                   padding: 18px;
#                   text-align: left;
#                   outline: none;
#                   font-size: 15px;
#                   font-weight: 700;
#                   border-radius: 5px 5px 5px 5px;
#                 }
#                 .active, .collapsible:hover {
#                   background-color: #555;
#                 }
#
#                 .container {
#                   display: none;
#                   background-color: inherit;
#                 }
#                 </style>
#           <div style="border:2px solid; border-radius: 15px; display: block; padding:2em; background: None"><div style= "font-size:large;color:None;font-weight:700">Apply if useful</div><div></div><button type="button" style="width: 97%; border: 1px solid #4E4E4E" class="collapsible collapsible_box"><span style= "font-size:{};color:#095600;font-weight:700">add_title : +0.022827610737974124</span></button><div style="border:2px solid; border-radius: 15px; display: none; padding:2em; background: None"><div></div><button type="button" style="width: 97%" class="collapsible">Processing</button><div class="div.input_area container"><div style= "font-size:initial;color:None;font-weight:400">add : Name</div><div style= "font-size:initial;color:None;font-weight:400">replace : fe_title_Name</div><div style= "font-size:initial;color:None;font-weight:400">ohe: fe_title_Name</div><div style= "font-size:initial;color:None;font-weight:400"></div></div>
#         <style>
#         hr {
#           display: block;
#           margin-top: 0.5em;
#           margin-bottom: 0.5em;
#           margin-left: auto;
#           margin-right: auto;
#           border-style: inset;
#           border-width: 1px;
#         }
#         </style> <hr><div></div><button type="button" style="width: 97%" class="collapsible">Training</button><div class="div.input_area container"><div style= "font-size:large;color:None;font-weight:700">Columns to use: </div><span style= "font-size:initial;color:None;font-weight:400">['Parch', 'Pclass_ohe', 'SibSp', 'fe_title_Name', 'label_encode_Sex', 'label_encode_Ticket', 'process_dense_Age', 'process_dense_Fare', 'process_dense_Fare_ohe', 'process_nominal_label_encode_Cabin', 'process_nominal_label_encode_Cabin_ohe', 'process_nominal_label_encode_Embarked']</span><div style= "font-size:initial;color:None;font-weight:400">Do line search</div><div style= "font-size:initial;color:None;font-weight:400"><b>NONSPARSE DTYPES:</b></div><div style= "font-size:initial;color:None;font-weight:400">Parch                                       int64</div><div style= "font-size:initial;color:None;font-weight:400">SibSp                                       int64</div><div style= "font-size:initial;color:None;font-weight:400">label_encode_Sex                         category</div><div style= "font-size:initial;color:None;font-weight:400">label_encode_Ticket                      category</div><div style= "font-size:initial;color:None;font-weight:400">process_dense_Age                         float64</div><div style= "font-size:initial;color:None;font-weight:400">process_dense_Fare                          int32</div><div style= "font-size:initial;color:None;font-weight:400">process_nominal_label_encode_Cabin        float64</div><div style= "font-size:initial;color:None;font-weight:400">process_nominal_label_encode_Embarked    category</div><div style= "font-size:initial;color:None;font-weight:400">dtype: object</div><div style= "font-size:initial;color:None;font-weight:400">Will not use high cardinality categoricals for linear models:</div><div style= "font-size:initial;color:None;font-weight:400">['label_encode_Ticket', 'process_nominal_label_encode_Embarked']</div><div style= "font-size:initial;color:None;font-weight:400"><b>STANDARDIZE:</b></div><div style= "font-size:initial;color:None;font-weight:400">Parch</div><div style= "font-size:initial;color:None;font-weight:400">SibSp</div><div style= "font-size:initial;color:None;font-weight:400">process_dense_Age</div><div style= "font-size:initial;color:None;font-weight:400">process_dense_Fare</div><div style= "font-size:initial;color:None;font-weight:400">process_nominal_label_encode_Cabin</div><div style= "font-size:initial;color:None;font-weight:400">label_encode_Sex</div><div style= "font-size:initial;color:None;font-weight:400"><b>TRN COLS TO USE:</b></div><div style= "font-size:initial;color:None;font-weight:400">{'fe_title_Name', 'process_nominal_label_encode_Cabin_ohe', 'label_encode_Sex_std', 'Pclass_ohe', 'process_dense_Fare_std', 'process_nominal_label_encode_Cabin_std', 'SibSp_std', 'process_dense_Fare_ohe', 'process_dense_Age_std', 'Parch_std'}</div><div style= "font-size:initial;color:None;font-weight:400">(891, 43)</div><div style= "font-size:initial;color:None;font-weight:400"><b>NONSPARSE DTYPES:</b></div><div style= "font-size:initial;color:None;font-weight:400">Parch                                       int64</div><div style= "font-size:initial;color:None;font-weight:400">SibSp                                       int64</div><div style= "font-size:initial;color:None;font-weight:400">label_encode_Sex                         category</div><div style= "font-size:initial;color:None;font-weight:400">label_encode_Ticket                      category</div><div style= "font-size:initial;color:None;font-weight:400">process_dense_Age                         float64</div><div style= "font-size:initial;color:None;font-weight:400">process_dense_Fare                          int32</div><div style= "font-size:initial;color:None;font-weight:400">process_nominal_label_encode_Cabin        float64</div><div style= "font-size:initial;color:None;font-weight:400">process_nominal_label_encod ...
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))

# %% [markdown]
# #### Add ticket prefix

# %%
def add_prefix(feature_properties, train, test, label_name, col_name):
    def prefix(df, col):
        def get_prefix(x):
            x = str(x)
            if len(x) == 1:
                return x
            else:
                return x.split(' ')[0][0]
        return df[col].apply(lambda x: get_prefix(x))
    
    utils.utilize(mode = 'add')(prefix)([train, test], col_name)
    new_name = f'prefix_{col_name}'
    utils.utilize(mode = 'replace')(prep.label_encode)([train, test], new_name)
    train, test = prep.one_hot_encode([train, test],
                                      col = new_name,
                                      mode = 'replace')
    return [], train, test

def add_prefix_group_outliers(
        feature_properties, train, test,
        label_name, col_name, limit = 10):
    @utils.utilize(mode = 'add')
    def prefix(df, col):
        def get_prefix(x):
            x = str(x)
            if len(x) == 1:
                return x
            else:
                return x.split(' ')[0][0]
        return df[col].apply(lambda x: get_prefix(x))

    prefix([train, test], col_name)
    new_name = f'prefix_{col_name}'
    utils.utilize(mode = 'replace')(prep.label_encode)([train, test], new_name)
    prep.group_outliers_replace([train, test], new_name, limit = limit)
    train, test = prep.one_hot_encode([train, test],
                                      col = new_name,
                                      mode = 'add')
    
    # Don't drop the original column, but don't use it in training
    return [col_name], train, test

lr_pipeline.add_step(proc = add_prefix,
                     group = 'prefix_ticket',
                     proc_params= {'col_name': 'Ticket'})

lr_pipeline.add_step(proc = add_prefix_group_outliers,
                     group = 'prefix_ticket',
                     proc_params= {'col_name': 'Ticket'})

res = lr_pipeline.group_apply_useful('prefix_ticket')
# Out:
#             <style>
#                 .collapsible {
#                   background-color: #777;
#                   color: white;
#                   cursor: pointer;
#                   padding: 18px;
#                   text-align: left;
#                   outline: none;
#                   font-size: 15px;
#                   font-weight: 700;
#                   border-radius: 5px 5px 5px 5px;
#                 }
#                 .active, .collapsible:hover {
#                   background-color: #555;
#                 }
#
#                 .container {
#                   display: none;
#                   background-color: inherit;
#                 }
#                 </style>
#           <div style="border:2px solid; border-radius: 15px; display: block; padding:2em; background: None"><div style= "font-size:large;color:None;font-weight:700">Steps to evaluate: </div><span style= "font-size:initial;color:None;font-weight:400">['add_prefix_(col_name=Ticket)', 'add_prefix_group_outliers_(col_name=Ticket)']</span><div></div><button type="button" style="width: 97%; border: 1px solid #4E4E4E" class="collapsible collapsible_box"><span style= "font-size:{};color:#680000;font-weight:700">add_prefix_(col_name=Ticket) : -0.004488104952608096</span></button><div style="border:2px solid; border-radius: 15px; display: none; padding:2em; background: None"><div></div><button type="button" style="width: 97%" class="collapsible">Processing</button><div class="div.input_area container"><div style= "font-size:initial;color:None;font-weight:400">add : Ticket</div><div style= "font-size:initial;color:None;font-weight:400">replace : prefix_Ticket</div><div style= "font-size:initial;color:None;font-weight:400">ohe: prefix_Ticket</div><div style= "font-size:initial;color:None;font-weight:400"></div></div>
#         <style>
#         hr {
#           display: block;
#           margin-top: 0.5em;
#           margin-bottom: 0.5em;
#           margin-left: auto;
#           margin-right: auto;
#           border-style: inset;
#           border-width: 1px;
#         }
#         </style> <hr><div></div><button type="button" style="width: 97%" class="collapsible">Training</button><div class="div.input_area container"><div style= "font-size:large;color:None;font-weight:700">Columns to use: </div><span style= "font-size:initial;color:None;font-weight:400">['Parch', 'Pclass_ohe', 'SibSp', 'fe_title_Name', 'label_encode_Sex', 'label_encode_Ticket', 'prefix_Ticket', 'process_dense_Age', 'process_dense_Fare', 'process_dense_Fare_ohe', 'process_nominal_label_encode_Cabin', 'process_nominal_label_encode_Cabin_ohe', 'process_nominal_label_encode_Embarked']</span><div style= "font-size:initial;color:None;font-weight:400">Do line search</div><div style= "font-size:initial;color:None;font-weight:400"><b>NONSPARSE DTYPES:</b></div><div style= "font-size:initial;color:None;font-weight:400">Parch                                       int64</div><div style= "font-size:initial;color:None;font-weight:400">SibSp                                       int64</div><div style= "font-size:initial;color:None;font-weight:400">label_encode_Sex                         category</div><div style= "font-size:initial;color:None;font-weight:400">label_encode_Ticket                      category</div><div style= "font-size:initial;color:None;font-weight:400">process_dense_Age                         float64</div><div style= "font-size:initial;color:None;font-weight:400">process_dense_Fare                          int32</div><div style= "font-size:initial;color:None;font-weight:400">process_nominal_label_encode_Cabin        float64</div><div style= "font-size:initial;color:None;font-weight:400">process_nominal_label_encode_Embarked    category</div><div style= "font-size:initial;color:None;font-weight:400">dtype: object</div><div style= "font-size:initial;color:None;font-weight:400">Will not use high cardinality categoricals for linear models:</div><div style= "font-size:initial;color:None;font-weight:400">['label_encode_Ticket', 'process_nominal_label_encode_Embarked']</div><div style= "font-size:initial;color:None;font-weight:400"><b>TRN COLS TO USE:</b></div><div style= "font-size:initial;color:None;font-weight:400">{'fe_title_Name', 'process_nominal_label_encode_Cabin_ohe', 'label_encode_Sex_std', 'Pclass_ohe', 'process_dense_Fare_std', 'process_nominal_label_encode_Cabin_std', 'SibSp_std', 'prefix_Ticket', 'process_dense_Fare_ohe', 'process_dense_Age_std', 'Parch_std'}</div><div style= "font-size:initial;color:None;font-weight:400">(891, 59)</div><div style= "font-size:initial;color:None;font-weight:400"><b>NONSPARSE DTYPES:</b></div><div style= "font-size:initial;color:None;font-weight:400">Parch                                       int64</div><div style= "font-size:initial;color:None;font-weight:400">SibSp                                       int64</div><div style= "font-size:initial;color:None;font-weight:400">label_encode_Sex                         category</div><div style= "font-size:initial;color:None;font-weight:400">label_encode_Ticket                      category</div><div style= "font-size:initial;color:None;font-weight:400">process_dense_Age                         float64</div><div style= "font-size:initial;color:None;font-weight:400">process_dense_Fare                          int32</div><div style= "font-size:initial;color:None;font-weight:400">process_nominal_label_encode_Cabin        float64</div><div style= "font-size:initial;color:None;font-weight:400">process_nominal_label_encode_Embarked    category</div><div style= "font-size:initial;color:None;font-weight:400">dtype: object</div><div style= "font-size:initial;color:None;font-weight:400">Will not use high cardinality categoricals for linear models:</div><div style= "font-size:initial;color:None;font-weight:400">['label_encode_Ticket', 'process_nominal_label_encode_Embarked']</div><div style= "font-size:initial;color:None;font-weight:400"><b>TRN COLS TO USE:</b></div><div style= "font-size:initial;color:None;font-weight:400">{'fe_title_Name', 'process_ ...

# %% [markdown]
# #### Add ticket integer part

# %%
@utils.utilize(mode = 'add')
def add_integer(df, col):
    def get_int(x):
        try:
            return int(x.split(' ')[-1])
        except:
            return -9000
    return df[col].apply(lambda x: get_int(x))

def ticket_integer(feature_properties, train, test, label_name):
    add_integer([train, test], 'Ticket')
    return [], train, test

def bin_ticket_integer(feature_properties, train, test, label_name, bins = 10):
    add_integer([train, test], 'Ticket')
    new_name = 'add_integer_Ticket'
    
    prep.full_binning([train, test], new_name, bins = bins)
    train, test = prep.one_hot_encode([train, test],
                                      new_name,
                                      mode = 'replace')
    return [], train, test

def auto_bin_ticket_integer(feature_properties, train, test, label_name): 
    add_integer([train, test], 'Ticket')
    new_name = 'add_integer_Ticket'
    
    print(train[new_name].dtype)
    prep.auto_bin_cols([train, test], new_name)
    train, test = prep.one_hot_encode([train, test],
                                      new_name,
                                      mode = 'replace')
    return [], train, test

lr_pipeline.add_step(proc = ticket_integer,
                     group = 'ticket_integer')

lr_pipeline.add_step(proc = bin_ticket_integer,
                     group = 'ticket_integer',
                     proc_params = {'bins': 10})

lr_pipeline.add_step(proc = auto_bin_ticket_integer,
                     group = 'ticket_integer')

res = lr_pipeline.group_apply_useful('ticket_integer')
# Out:
#             <style>
#                 .collapsible {
#                   background-color: #777;
#                   color: white;
#                   cursor: pointer;
#                   padding: 18px;
#                   text-align: left;
#                   outline: none;
#                   font-size: 15px;
#                   font-weight: 700;
#                   border-radius: 5px 5px 5px 5px;
#                 }
#                 .active, .collapsible:hover {
#                   background-color: #555;
#                 }
#
#                 .container {
#                   display: none;
#                   background-color: inherit;
#                 }
#                 </style>
#           <div style="border:2px solid; border-radius: 15px; display: block; padding:2em; background: None"><div style= "font-size:large;color:None;font-weight:700">Steps to evaluate: </div><span style= "font-size:initial;color:None;font-weight:400">['ticket_integer', 'bin_ticket_integer_(bins=10)', 'auto_bin_ticket_integer']</span><div></div><button type="button" style="width: 97%; border: 1px solid #4E4E4E" class="collapsible collapsible_box"><span style= "font-size:{};color:#680000;font-weight:700">ticket_integer : -0.0003724394785846741</span></button><div style="border:2px solid; border-radius: 15px; display: none; padding:2em; background: None"><div></div><button type="button" style="width: 97%" class="collapsible">Processing</button><div class="div.input_area container"><div style= "font-size:initial;color:None;font-weight:400">add : Ticket</div><div style= "font-size:initial;color:None;font-weight:400"></div></div>
#         <style>
#         hr {
#           display: block;
#           margin-top: 0.5em;
#           margin-bottom: 0.5em;
#           margin-left: auto;
#           margin-right: auto;
#           border-style: inset;
#           border-width: 1px;
#         }
#         </style> <hr><div></div><button type="button" style="width: 97%" class="collapsible">Training</button><div class="div.input_area container"><div style= "font-size:large;color:None;font-weight:700">Columns to use: </div><span style= "font-size:initial;color:None;font-weight:400">['Parch', 'Pclass_ohe', 'SibSp', 'add_integer_Ticket', 'fe_title_Name', 'label_encode_Sex', 'label_encode_Ticket', 'process_dense_Age', 'process_dense_Fare', 'process_dense_Fare_ohe', 'process_nominal_label_encode_Cabin', 'process_nominal_label_encode_Cabin_ohe', 'process_nominal_label_encode_Embarked']</span><div style= "font-size:initial;color:None;font-weight:400">Do line search</div><div style= "font-size:initial;color:None;font-weight:400"><b>NONSPARSE DTYPES:</b></div><div style= "font-size:initial;color:None;font-weight:400">Parch                                       int64</div><div style= "font-size:initial;color:None;font-weight:400">SibSp                                       int64</div><div style= "font-size:initial;color:None;font-weight:400">add_integer_Ticket                          int64</div><div style= "font-size:initial;color:None;font-weight:400">label_encode_Sex                         category</div><div style= "font-size:initial;color:None;font-weight:400">label_encode_Ticket                      category</div><div style= "font-size:initial;color:None;font-weight:400">process_dense_Age                         float64</div><div style= "font-size:initial;color:None;font-weight:400">process_dense_Fare                          int32</div><div style= "font-size:initial;color:None;font-weight:400">process_nominal_label_encode_Cabin        float64</div><div style= "font-size:initial;color:None;font-weight:400">process_nominal_label_encode_Embarked    category</div><div style= "font-size:initial;color:None;font-weight:400">dtype: object</div><div style= "font-size:initial;color:None;font-weight:400">Will not use high cardinality categoricals for linear models:</div><div style= "font-size:initial;color:None;font-weight:400">['label_encode_Ticket', 'process_nominal_label_encode_Embarked']</div><div style= "font-size:initial;color:None;font-weight:400"><b>STANDARDIZE:</b></div><div style= "font-size:initial;color:None;font-weight:400">add_integer_Ticket</div><div style= "font-size:initial;color:None;font-weight:400"><b>TRN COLS TO USE:</b></div><div style= "font-size:initial;color:None;font-weight:400">{'fe_title_Name', 'process_nominal_label_encode_Cabin_ohe', 'label_encode_Sex_std', 'Pclass_ohe', 'process_dense_Fare_std', 'process_nominal_label_encode_Cabin_std', 'SibSp_std', 'add_integer_Ticket_std', 'process_dense_Fare_ohe', 'process_dense_Age_std', 'Parch_std'}</div><div style= "font-size:initial;color:None;font-weight:400">(891, 44)</div><div style= "font-size:initial;color:None;font-weight:400"><b>NONSPARSE DTYPES:</b></div><div style= "font-size:initial;color:None;font-weight:400">Parch                                       int64</div><div style= "font-size:initial;color:None;font-weight:400">SibSp                                       int64</div><div style= "font-size:initial;color:None;font-weight:400">add_integer_Ticket                          int64</div><div style= "font-size:initial;color:None;font-weight:400">label_encode_Sex                         category</div><div style= "font-size:initial;color:None;font-weight:400">label_encode_Ticket                      category</div><div style= "font-size:initial;color:None;font-weight:400">process_dense_Age                         float64</div><div style= "font-size:initial;color:None;font-weight:400">process_dense_Fare                          int32</div><div style= "font-size:initial;color:None;font-weight:400">process_nominal_label_encode_Cabin        float64</div><div style= "font-size:initial;color:None;font-weight:400">process_nominal_label_encode_Embarked    category</div><div style= "font-size:initial;color:None;font-weight:400">dtype: object</div><div style= "font-si ...

# %% [markdown]
# ### Train models with bayesian search

# %% [markdown]
# ### LR

# %%
# When model is not specified, it is the baseline model
lr_pipeline.add_model('lr')
res = lr_pipeline.run_model('lr',
                            hyperparam_search = False,
                            return_pred = True,
                            use_final_params = True)
# Out:
#             <style>
#                 .collapsible {
#                   background-color: #777;
#                   color: white;
#                   cursor: pointer;
#                   padding: 18px;
#                   text-align: left;
#                   outline: none;
#                   font-size: 15px;
#                   font-weight: 700;
#                   border-radius: 5px 5px 5px 5px;
#                 }
#                 .active, .collapsible:hover {
#                   background-color: #555;
#                 }
#
#                 .container {
#                   display: none;
#                   background-color: inherit;
#                 }
#                 </style>
#           <div></div><button type="button" style="width: 97%; border: 1px solid #4E4E4E" class="collapsible collapsible_box"><span style= "font-size:{};color:#680000;font-weight:700">lr : 0.0</span></button><div style="border:2px solid; border-radius: 15px; display: none; padding:2em; background: None"><div style= "font-size:large;color:None;font-weight:700">Training lr</div>
#         <style>
#         hr {
#           display: block;
#           margin-top: 0.5em;
#           margin-bottom: 0.5em;
#           margin-left: auto;
#           margin-right: auto;
#           border-style: inset;
#           border-width: 1px;
#         }
#         </style> <hr><div style= "font-size:large;color:None;font-weight:700">Columns to use: </div><span style= "font-size:initial;color:None;font-weight:400">['Parch', 'Pclass_ohe', 'SibSp', 'Survived', 'add_integer_Ticket', 'fe_title_Name', 'label_encode_Sex', 'label_encode_Ticket', 'process_dense_Age', 'process_dense_Fare', 'process_dense_Fare_ohe', 'process_nominal_label_encode_Cabin', 'process_nominal_label_encode_Cabin_ohe', 'process_nominal_label_encode_Embarked']</span><div style= "font-size:large;color:None;font-weight:700">Columns not to use: </div><span style= "font-size:initial;color:None;font-weight:400">{'Sex', 'Embarked', 'SibSp_std', 'Ticket', 'label_encode_Sex_std', 'Name', 'label_encode_Cabin', 'Age', 'process_dense_Fare_std', 'Pclass', 'Cabin', 'label_encode_Embarked', 'PassengerId', 'Pclass_std', 'Fare', 'process_dense_Age_std', 'process_nominal_label_encode_Cabin_std', 'Parch_std'}</span><div style= "font-size:large;color:None;font-weight:700">Hyperparameters: </div><span style= "font-size:initial;color:None;font-weight:400">{'class_weight': None, 'solver': 'lbfgs', 'score': <function accuracy_score at 0x000002B8D4D75510>, 'model': <class 'sklearn.linear_model.logistic.LogisticRegression'>, 'max_iter': 5000, 'verbose': 0, 'n_jobs': 3, 'model_type': 'linear', 'folds': [KFold(n_splits=5, random_state=42, shuffle=True), KFold(n_splits=5, random_state=13, shuffle=True), KFold(n_splits=5, random_state=100, shuffle=True)], 'C': 0.5175815369042058}</span><div style= "font-size:initial;color:None;font-weight:400"><b>NONSPARSE DTYPES:</b></div><div style= "font-size:initial;color:None;font-weight:400">Parch                                       int64</div><div style= "font-size:initial;color:None;font-weight:400">SibSp                                       int64</div><div style= "font-size:initial;color:None;font-weight:400">label_encode_Sex                         category</div><div style= "font-size:initial;color:None;font-weight:400">label_encode_Ticket                      category</div><div style= "font-size:initial;color:None;font-weight:400">process_dense_Age                         float64</div><div style= "font-size:initial;color:None;font-weight:400">process_dense_Fare                          int32</div><div style= "font-size:initial;color:None;font-weight:400">process_nominal_label_encode_Cabin        float64</div><div style= "font-size:initial;color:None;font-weight:400">process_nominal_label_encode_Embarked    category</div><div style= "font-size:initial;color:None;font-weight:400">dtype: object</div><div style= "font-size:initial;color:None;font-weight:400">Will not use high cardinality categoricals for linear models:</div><div style= "font-size:initial;color:None;font-weight:400">['label_encode_Ticket', 'process_nominal_label_encode_Embarked']</div><div style= "font-size:initial;color:None;font-weight:400"><b>TRN COLS TO USE:</b></div><div style= "font-size:initial;color:None;font-weight:400">{'fe_title_Name', 'process_nominal_label_encode_Cabin_ohe', 'label_encode_Sex_std', 'Pclass_ohe', 'process_dense_Fare_std', 'process_nominal_label_encode_Cabin_std', 'SibSp_std', 'process_dense_Fare_ohe', 'add_integer_Ticket', 'process_dense_Age_std', 'Parch_std'}</div><div style= "font-size:initial;color:None;font-weight:400">(891, 82)</div><div style= "font-size:initial;color:None;font-weight:400"></div><div style= "font-size:large;color:Red;font-weight:700">Mean Metric: </div><span style= "font-size:initial;color:Red;font-weight:400">0.8398531165651875</span><div style= "font-size:large;color:None;font-weight:700">Difference from baseline: </div><span style= "font-size:initial;color:None;font-weight:400">0.0</span><div style= "font-size:initial;color:None;font-weight:400">Saving test predictions:</div><div style= "font-size:initial;color:None;font-weight:400">lr_pipeline\test_preds\lr_0.8398531165651875_20191201-111913.csv</div></div>      <script>
#                     var coll = document.getElementsByClassName("collapsible");
#                     var i;
#
#                     for (i = 0; i < coll.length; i++) {
#                       coll[i].addEventListener("click", function() {
#                         this.classList.toggle("active");
#                         var content = this.nextElementSibling;
#                         if (content.style.display === "none") {
#                           content.style.display = "block";
#                           this.style.borderBottomLeftRadius = "1px";
#                           this.style.borderBottomRightRadius = "1px";
#                           content.style.borderTopLeftRadius = "1px";
#                           content.style.borderTopRightRadius = "1px";
#
#                         } else {
#                             if (content.style.display === "block") {
#                               content.style.display = "none";
#                               this.style.borderBottomLeftRadius = "5px";
#                               this.style.borderBottomRightRadius = "5px";
#                               } else {
#                                   content.style.display = "block";
#                                   this.style.borderBottomLeftRadius = "1px";
#                                   this.style.borderBottomRightRadius = "1px";
#                                   content.style.borderTopLeftRadius = "1px";
#                                   content.style.borderTopRightRadius = "1px";
#                               }
#                         }
#                       });
#                     }
#                     </script>

# %% [markdown]
# ### SVC

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

fixed_hparams = dict(model = SVC,
                     probability = True,
                     random_state = 42,
                     score = accuracy_score,
                     max_iter = 2000,
                     folds=[KFold(n_splits= 5, shuffle = True, random_state = 42),
                              KFold(n_splits= 5, shuffle = True, random_state = 13),
                              KFold(n_splits= 5, shuffle = True, random_state = 100)
                              ])


search_hparams = dict(C = hp.loguniform('C', -3, 7),
                      gamma = hp.loguniform('gamma', -3, 3),
                      class_weight =  hp.choice('class_weight', ['balanced', None]),
                      kernel = hp.choice('kernel', ['linear', 'rbf', 'poly'])
                      )

lr_pipeline.add_model('svc',
                      model = pmodels.train_sklearn_pipeline,
                      fixed_hparams = fixed_hparams,
                      search_hparams = search_hparams)

res = lr_pipeline.run_model('svc', return_pred = True, hyperparam_search = True)
# Out:
#             <style>
#                 .collapsible {
#                   background-color: #777;
#                   color: white;
#                   cursor: pointer;
#                   padding: 18px;
#                   text-align: left;
#                   outline: none;
#                   font-size: 15px;
#                   font-weight: 700;
#                   border-radius: 5px 5px 5px 5px;
#                 }
#                 .active, .collapsible:hover {
#                   background-color: #555;
#                 }
#
#                 .container {
#                   display: none;
#                   background-color: inherit;
#                 }
#                 </style>
#           <div></div><button type="button" style="width: 97%; border: 1px solid #4E4E4E" class="collapsible collapsible_box"><span style= "font-size:{};color:#095600;font-weight:700">svc : +0.004875190927541517</span></button><div style="border:2px solid; border-radius: 15px; display: none; padding:2em; background: None"><div style= "font-size:large;color:None;font-weight:700">Training svc</div>
#         <style>
#         hr {
#           display: block;
#           margin-top: 0.5em;
#           margin-bottom: 0.5em;
#           margin-left: auto;
#           margin-right: auto;
#           border-style: inset;
#           border-width: 1px;
#         }
#         </style> <hr><div style= "font-size:large;color:None;font-weight:700">Columns to use: </div><span style= "font-size:initial;color:None;font-weight:400">['Parch', 'Pclass_ohe', 'SibSp', 'Survived', 'add_integer_Ticket', 'fe_title_Name', 'label_encode_Sex', 'label_encode_Ticket', 'process_dense_Age', 'process_dense_Fare', 'process_dense_Fare_ohe', 'process_nominal_label_encode_Cabin', 'process_nominal_label_encode_Cabin_ohe', 'process_nominal_label_encode_Embarked']</span><div style= "font-size:large;color:None;font-weight:700">Columns not to use: </div><span style= "font-size:initial;color:None;font-weight:400">{'Sex', 'Embarked', 'SibSp_std', 'Ticket', 'label_encode_Sex_std', 'Name', 'label_encode_Cabin', 'Age', 'process_dense_Fare_std', 'Pclass', 'Cabin', 'label_encode_Embarked', 'PassengerId', 'Pclass_std', 'Fare', 'process_dense_Age_std', 'process_nominal_label_encode_Cabin_std', 'Parch_std'}</span><div style= "font-size:initial;color:None;font-weight:400">Bayesian search: 1/1</div><div style= "font-size:initial;color:None;font-weight:400">Mean metric: 0.844728307492729</div><div style= "font-size:large;color:None;font-weight:700">Selected Params: </div><span style= "font-size:initial;color:None;font-weight:400">{'C': 9.828188246335166, 'class_weight': None, 'gamma': 0.05008674336627074, 'kernel': 'rbf', 'model': <class 'sklearn.svm.classes.SVC'>, 'probability': True, 'random_state': 42, 'score': <function accuracy_score at 0x000002B8D4D75510>, 'max_iter': 2000, 'folds': [KFold(n_splits=5, random_state=42, shuffle=True), KFold(n_splits=5, random_state=13, shuffle=True), KFold(n_splits=5, random_state=100, shuffle=True)]}</span><div style= "font-size:initial;color:None;font-weight:400">Saving hparams.</div><div style= "font-size:initial;color:None;font-weight:400">Set parameters as final parameters.</div><div style= "font-size:large;color:Green;font-weight:700">Mean Metric: </div><span style= "font-size:initial;color:Green;font-weight:400">0.844728307492729</span><div style= "font-size:large;color:None;font-weight:700">Difference from baseline: </div><span style= "font-size:initial;color:None;font-weight:400">0.004875190927541517</span><div style= "font-size:initial;color:None;font-weight:400">Saving test predictions:</div><div style= "font-size:initial;color:None;font-weight:400">lr_pipeline\test_preds\svc_0.844728307492729_20191201-112018.csv</div></div>      <script>
#                     var coll = document.getElementsByClassName("collapsible");
#                     var i;
#
#                     for (i = 0; i < coll.length; i++) {
#                       coll[i].addEventListener("click", function() {
#                         this.classList.toggle("active");
#                         var content = this.nextElementSibling;
#                         if (content.style.display === "none") {
#                           content.style.display = "block";
#                           this.style.borderBottomLeftRadius = "1px";
#                           this.style.borderBottomRightRadius = "1px";
#                           content.style.borderTopLeftRadius = "1px";
#                           content.style.borderTopRightRadius = "1px";
#
#                         } else {
#                             if (content.style.display === "block") {
#                               content.style.display = "none";
#                               this.style.borderBottomLeftRadius = "5px";
#                               this.style.borderBottomRightRadius = "5px";
#                               } else {
#                                   content.style.display = "block";
#                                   this.style.borderBottomLeftRadius = "1px";
#                                   this.style.borderBottomRightRadius = "1px";
#                                   content.style.borderTopLeftRadius = "1px";
#                                   content.style.borderTopRightRadius = "1px";
#                               }
#                         }
#                       });
#                     }
#                     </script>

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

fixed_hparams = dict(model = RandomForestClassifier,
                     folds = lr_pipeline.baseline_step['model_params']['folds'],
                     random_state = 42,
                     score = accuracy_score)


search_hparams = dict(min_samples_split = hp.uniform('min_samples_split', 0.05, 1.0),
                      min_samples_leaf = hp.uniform('min_samples_leaf', 0.05, 0.5),
                      class_weight =  hp.choice('class_weight', ['balanced', None]))

lr_pipeline.add_model('rf',
                      model = pmodels.train_sklearn_pipeline,
                      fixed_hparams = fixed_hparams,
                      search_hparams = search_hparams)

res = lr_pipeline.run_model('rf', hyperparam_search = True)
# Out:
#             <style>
#                 .collapsible {
#                   background-color: #777;
#                   color: white;
#                   cursor: pointer;
#                   padding: 18px;
#                   text-align: left;
#                   outline: none;
#                   font-size: 15px;
#                   font-weight: 700;
#                   border-radius: 5px 5px 5px 5px;
#                 }
#                 .active, .collapsible:hover {
#                   background-color: #555;
#                 }
#
#                 .container {
#                   display: none;
#                   background-color: inherit;
#                 }
#                 </style>
#           <div></div><button type="button" style="width: 97%; border: 1px solid #4E4E4E" class="collapsible collapsible_box"><span style= "font-size:{};color:#680000;font-weight:700">rf : -0.06804134496683634</span></button><div style="border:2px solid; border-radius: 15px; display: none; padding:2em; background: None"><div style= "font-size:large;color:None;font-weight:700">Training rf</div>
#         <style>
#         hr {
#           display: block;
#           margin-top: 0.5em;
#           margin-bottom: 0.5em;
#           margin-left: auto;
#           margin-right: auto;
#           border-style: inset;
#           border-width: 1px;
#         }
#         </style> <hr><div style= "font-size:large;color:None;font-weight:700">Columns to use: </div><span style= "font-size:initial;color:None;font-weight:400">['Parch', 'Pclass_ohe', 'SibSp', 'Survived', 'add_integer_Ticket', 'fe_title_Name', 'label_encode_Sex', 'label_encode_Ticket', 'process_dense_Age', 'process_dense_Fare', 'process_dense_Fare_ohe', 'process_nominal_label_encode_Cabin', 'process_nominal_label_encode_Cabin_ohe', 'process_nominal_label_encode_Embarked']</span><div style= "font-size:large;color:None;font-weight:700">Columns not to use: </div><span style= "font-size:initial;color:None;font-weight:400">{'Sex', 'Embarked', 'SibSp_std', 'Ticket', 'label_encode_Sex_std', 'Name', 'label_encode_Cabin', 'Age', 'process_dense_Fare_std', 'Pclass', 'Cabin', 'label_encode_Embarked', 'PassengerId', 'Pclass_std', 'Fare', 'process_dense_Age_std', 'process_nominal_label_encode_Cabin_std', 'Parch_std'}</span><div style= "font-size:initial;color:None;font-weight:400">Bayesian search: 1/1</div><div style= "font-size:initial;color:None;font-weight:400">Mean metric: 0.7718117715983511</div><div style= "font-size:large;color:None;font-weight:700">Selected Params: </div><span style= "font-size:initial;color:None;font-weight:400">{'class_weight': None, 'min_samples_leaf': 0.1999290117679402, 'min_samples_split': 0.23537543780145564, 'model': <class 'sklearn.ensemble.forest.RandomForestClassifier'>, 'folds': [KFold(n_splits=5, random_state=42, shuffle=True), KFold(n_splits=5, random_state=13, shuffle=True), KFold(n_splits=5, random_state=100, shuffle=True)], 'random_state': 42, 'score': <function accuracy_score at 0x000002B8D4D75510>}</span><div style= "font-size:large;color:Red;font-weight:700">Mean Metric: </div><span style= "font-size:initial;color:Red;font-weight:400">0.7718117715983511</span><div style= "font-size:large;color:None;font-weight:700">Difference from baseline: </div><span style= "font-size:initial;color:None;font-weight:400">-0.06804134496683634</span><div style= "font-size:initial;color:None;font-weight:400">Saving test predictions:</div><div style= "font-size:initial;color:None;font-weight:400">lr_pipeline\test_preds\rf_0.7718117715983511_20191201-112028.csv</div></div>      <script>
#                     var coll = document.getElementsByClassName("collapsible");
#                     var i;
#
#                     for (i = 0; i < coll.length; i++) {
#                       coll[i].addEventListener("click", function() {
#                         this.classList.toggle("active");
#                         var content = this.nextElementSibling;
#                         if (content.style.display === "none") {
#                           content.style.display = "block";
#                           this.style.borderBottomLeftRadius = "1px";
#                           this.style.borderBottomRightRadius = "1px";
#                           content.style.borderTopLeftRadius = "1px";
#                           content.style.borderTopRightRadius = "1px";
#
#                         } else {
#                             if (content.style.display === "block") {
#                               content.style.display = "none";
#                               this.style.borderBottomLeftRadius = "5px";
#                               this.style.borderBottomRightRadius = "5px";
#                               } else {
#                                   content.style.display = "block";
#                                   this.style.borderBottomLeftRadius = "1px";
#                                   this.style.borderBottomRightRadius = "1px";
#                                   content.style.borderTopLeftRadius = "1px";
#                                   content.style.borderTopRightRadius = "1px";
#                               }
#                         }
#                       });
#                     }
#                     </script>

# %% [markdown]
# ### KNeighbors

# %%
from sklearn.neighbors import KNeighborsClassifier

fixed_hparams = dict(model = KNeighborsClassifier,
                     folds = lr_pipeline.baseline_step['model_params']['folds'],
                     score = accuracy_score)


search_hparams = dict(n_neighbors  = hp.choice('n_neighbors', np.arange(4,25)),
                      leaf_size = hp.choice('leaf_size', np.arange(15,50)))

lr_pipeline.add_model('kn',
                      model = pmodels.train_sklearn_pipeline,
                      fixed_hparams = fixed_hparams,
                      search_hparams = search_hparams)

res = lr_pipeline.run_model('kn', hyperparam_search = True)
# Out:
#             <style>
#                 .collapsible {
#                   background-color: #777;
#                   color: white;
#                   cursor: pointer;
#                   padding: 18px;
#                   text-align: left;
#                   outline: none;
#                   font-size: 15px;
#                   font-weight: 700;
#                   border-radius: 5px 5px 5px 5px;
#                 }
#                 .active, .collapsible:hover {
#                   background-color: #555;
#                 }
#
#                 .container {
#                   display: none;
#                   background-color: inherit;
#                 }
#                 </style>
#           <div></div><button type="button" style="width: 97%; border: 1px solid #4E4E4E" class="collapsible collapsible_box"><span style= "font-size:{};color:#680000;font-weight:700">kn : -0.008961563408867446</span></button><div style="border:2px solid; border-radius: 15px; display: none; padding:2em; background: None"><div style= "font-size:large;color:None;font-weight:700">Training kn</div>
#         <style>
#         hr {
#           display: block;
#           margin-top: 0.5em;
#           margin-bottom: 0.5em;
#           margin-left: auto;
#           margin-right: auto;
#           border-style: inset;
#           border-width: 1px;
#         }
#         </style> <hr><div style= "font-size:large;color:None;font-weight:700">Columns to use: </div><span style= "font-size:initial;color:None;font-weight:400">['Parch', 'Pclass_ohe', 'SibSp', 'Survived', 'add_integer_Ticket', 'fe_title_Name', 'label_encode_Sex', 'label_encode_Ticket', 'process_dense_Age', 'process_dense_Fare', 'process_dense_Fare_ohe', 'process_nominal_label_encode_Cabin', 'process_nominal_label_encode_Cabin_ohe', 'process_nominal_label_encode_Embarked']</span><div style= "font-size:large;color:None;font-weight:700">Columns not to use: </div><span style= "font-size:initial;color:None;font-weight:400">{'Sex', 'Embarked', 'SibSp_std', 'Ticket', 'label_encode_Sex_std', 'Name', 'label_encode_Cabin', 'Age', 'process_dense_Fare_std', 'Pclass', 'Cabin', 'label_encode_Embarked', 'PassengerId', 'Pclass_std', 'Fare', 'process_dense_Age_std', 'process_nominal_label_encode_Cabin_std', 'Parch_std'}</span><div style= "font-size:initial;color:None;font-weight:400">Bayesian search: 1/1</div><div style= "font-size:initial;color:None;font-weight:400">Mean metric: 0.83089155315632</div><div style= "font-size:large;color:None;font-weight:700">Selected Params: </div><span style= "font-size:initial;color:None;font-weight:400">{'leaf_size': 23, 'n_neighbors': 5, 'model': <class 'sklearn.neighbors.classification.KNeighborsClassifier'>, 'folds': [KFold(n_splits=5, random_state=42, shuffle=True), KFold(n_splits=5, random_state=13, shuffle=True), KFold(n_splits=5, random_state=100, shuffle=True)], 'score': <function accuracy_score at 0x000002B8D4D75510>}</span><div style= "font-size:large;color:Red;font-weight:700">Mean Metric: </div><span style= "font-size:initial;color:Red;font-weight:400">0.83089155315632</span><div style= "font-size:large;color:None;font-weight:700">Difference from baseline: </div><span style= "font-size:initial;color:None;font-weight:400">-0.008961563408867446</span><div style= "font-size:initial;color:None;font-weight:400">Saving test predictions:</div><div style= "font-size:initial;color:None;font-weight:400">lr_pipeline\test_preds\kn_0.83089155315632_20191201-112048.csv</div></div>      <script>
#                     var coll = document.getElementsByClassName("collapsible");
#                     var i;
#
#                     for (i = 0; i < coll.length; i++) {
#                       coll[i].addEventListener("click", function() {
#                         this.classList.toggle("active");
#                         var content = this.nextElementSibling;
#                         if (content.style.display === "none") {
#                           content.style.display = "block";
#                           this.style.borderBottomLeftRadius = "1px";
#                           this.style.borderBottomRightRadius = "1px";
#                           content.style.borderTopLeftRadius = "1px";
#                           content.style.borderTopRightRadius = "1px";
#
#                         } else {
#                             if (content.style.display === "block") {
#                               content.style.display = "none";
#                               this.style.borderBottomLeftRadius = "5px";
#                               this.style.borderBottomRightRadius = "5px";
#                               } else {
#                                   content.style.display = "block";
#                                   this.style.borderBottomLeftRadius = "1px";
#                                   this.style.borderBottomRightRadius = "1px";
#                                   content.style.borderTopLeftRadius = "1px";
#                                   content.style.borderTopRightRadius = "1px";
#                               }
#                         }
#                       });
#                     }
#                     </script>

# %% [markdown]
# #### Create submission

# %%
# Convert to (1,0) from probabilities
test_preds = (res['test_preds'] > 0.7).astype('int')

# Print mean to adjust threshold
print(test_preds.mean())

# Save submission
sub = pd.read_csv(r'data/gender_submission.csv')
to_sub = sub.copy()
to_sub[lr_pipeline.label_name] = test_preds
to_sub.to_csv('titanic_sub.csv', index = False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-ef13f60acd34> in <module>
#       1 # Convert to (1,0) from probabilities
# ----> 2 test_preds = (res['test_preds'] > 0.7).astype('int')
#       3
#       4 # Print mean to adjust threshold
#       5 print(test_preds.mean())
#
# C:\ProgramData\Anaconda3\envs\dl2\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#    1066         key = com.apply_if_callable(key, self)
#    1067         try:
# -> 1068             result = self.index.get_value(self, key)
#    1069
#    1070             if not is_scalar(result):
#
# C:\ProgramData\Anaconda3\envs\dl2\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4728         k = self._convert_scalar_indexer(k, kind="getitem")
#    4729         try:
# -> 4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4731         except KeyError as e1:
#    4732             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'test_preds'

# %% [markdown]
# ### Blending

# %%
res = putils.blend_from_csv(directory = lr_pipeline.test_preds_path)

# Convert to (1,0) from probabilities
test_preds = (res > 0.655).astype('int')

# Print mean to adjust threshold
print(test_preds.mean())

# Save submission
sub = pd.read_csv(r'data/gender_submission.csv')
to_sub = sub.copy()
to_sub[lr_pipeline.label_name] = test_preds
to_sub.to_csv('titanic_sub.csv', index = False)
# Out:
# 0.3827751196172249
